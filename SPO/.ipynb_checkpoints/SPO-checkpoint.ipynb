# %% [markdown]
# # СПО

# %%
import pandas as pd
import numpy as np
from sklearn import cross_validation as cv
import sklearn.linear_model as lm
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
# %matplotlib inline

# %%
data = pd.read_csv("data.csv")
data
# Out:
#     lab1  lab2  lab3    hw  lab4    total
# 0   4.30   4.5   5.0  4.00   4.5  88.2250
# 1   4.50   3.0   3.5   NaN   3.0  63.9000
# 2   5.00   5.0   4.9  5.00   5.0  75.5910
# 3   4.00   4.5   3.0  4.00   5.0  75.1660
# 4   4.00   4.0   3.9  3.00   3.0  60.0050
# 5   4.00   4.3   5.0  4.00   5.0  75.1750
# 6   4.00   3.0   3.0  3.00   3.0  60.1500
# 7   4.00   4.5   3.0  3.00   3.0  62.1250
# 8   4.90   4.0   4.0   NaN   3.0  74.5250
# 9   4.00   4.0   3.5  4.00   4.5  77.2500
# 10  4.00   4.7   4.0  4.00   3.5  75.3250
# 11  3.00   3.0   5.0  3.00   4.0  75.1750
# 12  3.50   3.0   3.0  4.00   3.0  60.8250
# 13  1.00   NaN   NaN  3.00   NaN  28.0000
# 14   NaN   NaN   NaN   NaN   NaN   0.0000
# 15  3.00   3.0   3.0  3.00   3.0  60.6000
# 16  3.00   3.0   3.0  3.00   3.0  60.6000
# 17  4.00   4.0   3.0  4.00   4.0  61.0500
# 18  4.00   4.0   4.0  5.00   4.5  84.0150
# 19  4.00   5.0   4.5  5.00   5.0  77.8800
# 20  4.00   4.0   4.0  5.00   4.0  75.6500
# ...

# %%
data = data_d.dropna()
sns.pairplot(data)
plt.savefig("dependencies.png")

# %%
corr = data.corr()
plt.figure(figsize=(12, 12))
sns.heatmap(corr, vmax=1, square = True )
plt.savefig("corr.png")

# %%
y = data.lab4
X = data[["lab1", "lab2", "lab3", "hw"]]
X 
X_me = [4, 4, 4, 4]

# %%
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

#scaler = StandardScaler()
#X = scaler.fit_transform(X)
#X_me = scaler.transform(X_me)

poly = PolynomialFeatures()
X_poly = poly.fit_transform(X)

# %% [markdown]
# # Lasso CV

# %%
estimator = lm.LassoCV()
print abs(cv.cross_val_score(estimator, X=X, y=y , cv=5, scoring="mean_absolute_error")).mean()

estimator = lm.LassoCV()
print abs(cv.cross_val_score(estimator, X=X_poly, y=y , cv=5, scoring="mean_absolute_error")).mean()

params = { 'normalize' : (True, False),
           'positive' : (True, False),
           'n_alphas' : range(1, 100, 30),
           'max_iter' : range(1, 10000, 3000)}
grid = grid_search.GridSearchCV(estimator, params, n_jobs=3)
grid.fit(X, y)
print grid.best_score_
print grid.best_estimator_.decision_function
print grid.predict(X_me)
X
# Out:
# 0.509661521693
# 0.545692513393
# 0.321500101523
# <bound method LassoCV.decision_function of LassoCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#     max_iter=3001, n_alphas=61, n_jobs=1, normalize=True, positive=True,
#     precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#     verbose=False)>
# [ 3.97695466]
# /home/yurijvolkov/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
#     lab1  lab2  lab3    hw
# 0   4.30   4.5  5.00  4.00
# 2   5.00   5.0  4.90  5.00
# 3   4.00   4.5  3.00  4.00
# 4   4.00   4.0  3.90  3.00
# 5   4.00   4.3  5.00  4.00
# 6   4.00   3.0  3.00  3.00
# 7   4.00   4.5  3.00  3.00
# 9   4.00   4.0  3.50  4.00
# 10  4.00   4.7  4.00  4.00
# ...

# %%
print grid.best_estimator_.predict(X_me)
grid.best_estimator_.predict([0,0,0,0])
grid.best_estimator_.intercept_
# Out:
# [ 3.97695466]
# /home/yurijvolkov/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# /home/yurijvolkov/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# 0.99665755095890196

# %% [markdown]
# # Random forest

# %%
import sklearn.ensemble as ens
import sklearn.grid_search as grid_search

# %%
estimator = ens.RandomForestRegressor()
print abs(cv.cross_val_score(estimator, X, y=y , cv=5, scoring="mean_absolute_error")).mean()

estimator = ens.RandomForestRegressor()
print abs(cv.cross_val_score(estimator, X=X_poly, y=y , cv=5, scoring="mean_absolute_error")).mean()

params = {'bootstrap' : (True, False), 
          'max_depth' :(None, 3, 7, 20, 50)}
grid = grid_search.GridSearchCV(estimator, params, n_jobs=3)
grid.fit(X, y)
print grid.best_score_
print grid.predict(X_me)
# Out:
# 0.52814029304
# 0.520891208791
# 0.223636539173
# [ 4.43833333]
# /home/yurijvolkov/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %% [markdown]
# # Gradient boosting

# %%
import sys
estimator = ens.GradientBoostingRegressor()
print abs(cv.cross_val_score(estimator, X=X, y=y , cv=5, scoring="mean_absolute_error")).mean()

estimator = ens.GradientBoostingRegressor()
print abs(cv.cross_val_score(estimator, X=X_poly, y=y , cv=5, scoring="mean_absolute_error")).mean()

params = {'alpha' : ( 0.5, 0.7, 0.9),
          'learning_rate' : (0.1, 0.5),
          'max_depth' : ( 1, 3, 10),
          'n_estimators' : (50, 100, 300)}
grid = grid_search.GridSearchCV(estimator, params, n_jobs=3)
print "asd"
grid.fit(X, y)
print grid.best_score_
print grid.predict(X_me)
# Out:
# 0.516478571275
# 0.534092677142
# asd
# 0.286654034962
# [ 4.20786971]
# /home/yurijvolkov/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %% [markdown]
# # KNN

# %%
import sklearn.neighbors as nb

# %%
estimator = nb.KNeighborsRegressor()
print abs(cv.cross_val_score(estimator, X=X, y=y , cv=5, scoring="mean_absolute_error")).mean()

estimator = nb.KNeighborsRegressor()
print abs(cv.cross_val_score(estimator, X=X_poly, y=y , cv=5, scoring="mean_absolute_error")).mean()


estimator.fit(X, y)
estimator.predict(X_me)
# Out:
# 0.56189010989
# 0.571934065934
# /home/yurijvolkov/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([ 4.64])

# %% [markdown]
# # Neural network

# %%
from sklearn.neural_network import MLPRegressor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-168-5a9f8e06d1ac> in <module>()
# ----> 1 from sklearn.neural_network import MLPRegressor
#
# ImportError: cannot import name MLPRegressor

# %%
estimator = n_n.
